# %% [markdown]
# # 베스트 모델 만들기 - 와인 사례
# ## 이진 분류
# ## 베스트 모델 업데이트하기

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint, EarlyStopping

import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# seed 값 설정
seed = 0
np.random.seed(seed)
tf.set_random_seed(seed)

# %%
# 데이터 입력
df_pre = pd.read_csv('../dataset/wine.csv', header=None)
df = df_pre.sample(frac=1)
dataset = df.values
X = dataset[:,0:12]
Y = dataset[:,12]

# %%
# 모델 설정
model = Sequential() 
model.add(Dense(30, input_dim=12, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
# 모델 컴파일 
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
# 모델 저장 폴더 설정
import os
MODEL_DIR = './model2/'
if not os.path.exists(MODEL_DIR):
    os.mkdir(MODEL_DIR)

# %%
# 모델 저장 조건 설정
modelpath="./model2/{epoch:02d}-{val_loss:.4f}.hdf5"

# checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1)
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', 
                               verbose=1, save_best_only=True)

# %%
# 모델 실행 및 저장
model.fit(X, Y, validation_split=0.2, epochs=200, batch_size=200, 
          verbose=0, callbacks=[checkpointer])
# Out:
# W0812 11:04:59.008954  5052 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Epoch 00001: val_loss improved from inf to 0.26758, saving model to ./model2/01-0.2676.hdf5
#
# Epoch 00002: val_loss improved from 0.26758 to 0.24035, saving model to ./model2/02-0.2404.hdf5
#
# Epoch 00003: val_loss improved from 0.24035 to 0.23056, saving model to ./model2/03-0.2306.hdf5
#
# Epoch 00004: val_loss improved from 0.23056 to 0.21570, saving model to ./model2/04-0.2157.hdf5
#
# Epoch 00005: val_loss improved from 0.21570 to 0.20827, saving model to ./model2/05-0.2083.hdf5
#
# Epoch 00006: val_loss improved from 0.20827 to 0.20455, saving model to ./model2/06-0.2046.hdf5
#
# Epoch 00007: val_loss improved from 0.20455 to 0.19892, saving model to ./model2/07-0.1989.hdf5
#
# Epoch 00008: val_loss improved from 0.19892 to 0.19458, saving model to ./model2/08-0.1946.hdf5
#
# Epoch 00009: val_loss improved from 0.19458 to 0.19363, saving model to ./model2/09-0.1936.hdf5
#
# Epoch 00010: val_loss improved from 0.19363 to 0.19258, saving model to ./model2/10-0.1926.hdf5
#
# Epoch 00011: val_loss improved from 0.19258 to 0.18226, saving model to ./model2/11-0.1823.hdf5
#
# Epoch 00012: val_loss improved from 0.18226 to 0.18202, saving model to ./model2/12-0.1820.hdf5
#
# Epoch 00013: val_loss improved from 0.18202 to 0.17013, saving model to ./model2/13-0.1701.hdf5
#
# Epoch 00014: val_loss improved from 0.17013 to 0.16498, saving model to ./model2/14-0.1650.hdf5
#
# Epoch 00015: val_loss improved from 0.16498 to 0.15727, saving model to ./model2/15-0.1573.hdf5
#
# Epoch 00016: val_loss improved from 0.15727 to 0.15438, saving model to ./model2/16-0.1544.hdf5
#
# Epoch 00017: val_loss improved from 0.15438 to 0.15117, saving model to ./model2/17-0.1512.hdf5
#
# Epoch 00018: val_loss improved from 0.15117 to 0.14152, saving model to ./model2/18-0.1415.hdf5
#
# Epoch 00019: val_loss did not improve from 0.14152
#
# Epoch 00020: val_loss improved from 0.14152 to 0.13116, saving model to ./model2/20-0.1312.hdf5
#
# Epoch 00021: val_loss did not improve from 0.13116
#
# Epoch 00022: val_loss improved from 0.13116 to 0.12129, saving model to ./model2/22-0.1213.hdf5
#
# Epoch 00023: val_loss did not improve from 0.12129
#
# Epoch 00024: val_loss did not improve from 0.12129
#
# Epoch 00025: val_loss improved from 0.12129 to 0.11341, saving model to ./model2/25-0.1134.hdf5
#
# Epoch 00026: val_loss improved from 0.11341 to 0.10895, saving model to ./model2/26-0.1090.hdf5
#
# Epoch 00027: val_loss did not improve from 0.10895
#
# Epoch 00028: val_loss improved from 0.10895 to 0.10500, saving model to ./model2/28-0.1050.hdf5
#
# Epoch 00029: val_loss improved from 0.10500 to 0.10369, saving model to ./model2/29-0.1037.hdf5
#
# Epoch 00030: val_loss improved from 0.10369 to 0.10283, saving model to ./model2/30-0.1028.hdf5
#
# Epoch 00031: val_loss did not improve from 0.10283
#
# Epoch 00032: val_loss did not improve from 0.10283
#
# Epoch 00033: val_loss improved from 0.10283 to 0.09657, saving model to ./model2/33-0.0966.hdf5
#
# Epoch 00034: val_loss did not improve from 0.09657
#
# Epoch 00035: val_loss improved from 0.09657 to 0.09491, saving model to ./model2/35-0.0949.hdf5
#
# Epoch 00036: val_loss improved from 0.09491 to 0.09252, saving model to ./model2/36-0.0925.hdf5
#
# Epoch 00037: val_loss did not improve from 0.09252
#
# Epoch 00038: val_loss improved from 0.09252 to 0.08800, saving model to ./model2/38-0.0880.hdf5
#
# Epoch 00039: val_loss improved from 0.08800 to 0.08055, saving model to ./model2/39-0.0806.hdf5
#
# Epoch 00040: val_loss did not improve from 0.08055
#
# Epoch 00041: val_loss improved from 0.08055 to 0.08037, saving model to ./model2/41-0.0804.hdf5
#
# Epoch 00042: val_loss improved from 0.08037 to 0.07922, saving model to ./model2/42-0.0792.hdf5
#
# Epoch 00043: val_loss improved from 0.07922 to 0.07891, saving model to ./model2/43-0.0789.hdf5
#
# Epoch 00044: val_loss improved from 0.07891 to 0.07729, saving model to ./model2/44-0.0773.hdf5
#
# Epoch 00045: val_loss improved from 0.07729 to 0.07467, saving model to ./model2/45-0.0747.hdf5
#
# Epoch 00046: val_loss did not improve from 0.07467
#
# Epoch 00047: val_loss improved from 0.07467 to 0.07298, saving model to ./model2/47-0.0730.hdf5
#
# Epoch 00048: val_loss improved from 0.07298 to 0.07067, saving model to ./model2/48-0.0707.hdf5
#
# Epoch 00049: val_loss improved from 0.07067 to 0.06904, saving model to ./model2/49-0.0690.hdf5
#
# Epoch 00050: val_loss did not improve from 0.06904
#
# Epoch 00051: val_loss improved from 0.06904 to 0.06791, saving model to ./model2/51-0.0679.hdf5
#
# Epoch 00052: val_loss did not improve from 0.06791
#
# Epoch 00053: val_loss did not improve from 0.06791
#
# Epoch 00054: val_loss did not improve from 0.06791
#
# Epoch 00055: val_loss did not improve from 0.06791
#
# Epoch 00056: val_loss did not improve from 0.06791
#
# Epoch 00057: val_loss did not improve from 0.06791
#
# Epoch 00058: val_loss did not improve from 0.06791
#
# Epoch 00059: val_loss did not improve from 0.06791
#
# Epoch 00060: val_loss improved from 0.06791 to 0.06559, saving model to ./model2/60-0.0656.hdf5
#
# Epoch 00061: val_loss did not improve from 0.06559
#
# Epoch 00062: val_loss improved from 0.06559 to 0.06251, saving model to ./model2/62-0.0625.hdf5
#
# Epoch 00063: val_loss did not improve from 0.06251
#
# Epoch 00064: val_loss improved from 0.06251 to 0.06218, saving model to ./model2/64-0.0622.hdf5
#
# Epoch 00065: val_loss did not improve from 0.06218
#
# Epoch 00066: val_loss improved from 0.06218 to 0.06067, saving model to ./model2/66-0.0607.hdf5
#
# Epoch 00067: val_loss improved from 0.06067 to 0.06044, saving model to ./model2/67-0.0604.hdf5
#
# Epoch 00068: val_loss did not improve from 0.06044
#
# Epoch 00069: val_loss did not improve from 0.06044
#
# Epoch 00070: val_loss did not improve from 0.06044
#
# Epoch 00071: val_loss did not improve from 0.06044
#
# Epoch 00072: val_loss improved from 0.06044 to 0.05860, saving model to ./model2/72-0.0586.hdf5
#
# Epoch 00073: val_loss did not improve from 0.05860
#
# Epoch 00074: val_loss did not improve from 0.05860
#
# Epoch 00075: val_loss did not improve from 0.05860
#
# Epoch 00076: val_loss did not improve from 0.05860
#
# Epoch 00077: val_loss did not improve from 0.05860
#
# Epoch 00078: val_loss did not improve from 0.05860
#
# Epoch 00079: val_loss did not improve from 0.05860
#
# Epoch 00080: val_loss improved from 0.05860 to 0.05718, saving model to ./model2/80-0.0572.hdf5
#
# Epoch 00081: val_loss did not improve from 0.05718
#
# Epoch 00082: val_loss did not improve from 0.05718
#
# Epoch 00083: val_loss did not improve from 0.05718
#
# Epoch 00084: val_loss did not improve from 0.05718
#
# Epoch 00085: val_loss did not improve from 0.05718
#
# Epoch 00086: val_loss did not improve from 0.05718
#
# Epoch 00087: val_loss did not improve from 0.05718
#
# Epoch 00088: val_loss did not improve from 0.05718
#
# Epoch 00089: val_loss did not improve from 0.05718
#
# Epoch 00090: val_loss improved from 0.05718 to 0.05524, saving model to ./model2/90-0.0552.hdf5
#
# Epoch 00091: val_loss improved from 0.05524 to 0.05467, saving model to ./model2/91-0.0547.hdf5
#
# Epoch 00092: val_loss did not improve from 0.05467
#
# Epoch 00093: val_loss did not improve from 0.05467
#
# Epoch 00094: val_loss did not improve from 0.05467
#
# Epoch 00095: val_loss did not improve from 0.05467
#
# Epoch 00096: val_loss did not improve from 0.05467
#
# Epoch 00097: val_loss did not improve from 0.05467
#
# Epoch 00098: val_loss did not improve from 0.05467
#
# Epoch 00099: val_loss did not improve from 0.05467
#
# Epoch 00100: val_loss did not improve from 0.05467
#
# Epoch 00101: val_loss did not improve from 0.05467
#
# Epoch 00102: val_loss did not improve from 0.05467
#
# Epoch 00103: val_loss did not improve from 0.05467
#
# Epoch 00104: val_loss did not improve from 0.05467
#
# Epoch 00105: val_loss improved from 0.05467 to 0.05399, saving model to ./model2/105-0.0540.hdf5
#
# Epoch 00106: val_loss did not improve from 0.05399
#
# Epoch 00107: val_loss improved from 0.05399 to 0.05356, saving model to ./model2/107-0.0536.hdf5
#
# Epoch 00108: val_loss did not improve from 0.05356
#
# Epoch 00109: val_loss did not improve from 0.05356
#
# Epoch 00110: val_loss did not improve from 0.05356
#
# Epoch 00111: val_loss did not improve from 0.05356
#
# Epoch 00112: val_loss did not improve from 0.05356
#
# Epoch 00113: val_loss did not improve from 0.05356
#
# Epoch 00114: val_loss did not improve from 0.05356
#
# Epoch 00115: val_loss did not improve from 0.05356
#
# Epoch 00116: val_loss did not improve from 0.05356
#
# Epoch 00117: val_loss improved from 0.05356 to 0.05308, saving model to ./model2/117-0.0531.hdf5
#
# Epoch 00118: val_loss did not improve from 0.05308
#
# Epoch 00119: val_loss did not improve from 0.05308
#
# Epoch 00120: val_loss did not improve from 0.05308
#
# Epoch 00121: val_loss did not improve from 0.05308
# Epoch 00122: val_loss did not improve from 0.05308
#
# Epoch 00123: val_loss did not improve from 0.05308
#
# Epoch 00124: val_loss improved from 0.05308 to 0.05292, saving model to ./model2/124-0.0529.hdf5
#
# Epoch 00125: val_loss did not improve from 0.05292
#
# Epoch 00126: val_loss did not improve from 0.05292
#
# Epoch 00127: val_loss did not improve from 0.05292
#
# Epoch 00128: val_loss did not improve from 0.05292
#
# Epoch 00129: val_loss did not improve from 0.05292
#
# Epoch 00130: val_loss did not improve from 0.05292
#
# Epoch 00131: val_loss did not improve from 0.05292
#
# Epoch 00132: val_loss did not improve from 0.05292
#
# Epoch 00133: val_loss did not improve from 0.05292
#
# Epoch 00134: val_loss did not improve from 0.05292
#
# Epoch 00135: val_loss did not improve from 0.05292
#
# Epoch 00136: val_loss did not improve from 0.05292
#
# Epoch 00137: val_loss improved from 0.05292 to 0.05220, saving model to ./model2/137-0.0522.hdf5
#
# Epoch 00138: val_loss did not improve from 0.05220
#
# Epoch 00139: val_loss did not improve from 0.05220
#
# Epoch 00140: val_loss did not improve from 0.05220
#
# Epoch 00141: val_loss did not improve from 0.05220
#
# Epoch 00142: val_loss did not improve from 0.05220
#
# Epoch 00143: val_loss did not improve from 0.05220
#
# Epoch 00144: val_loss did not improve from 0.05220
#
# Epoch 00145: val_loss did not improve from 0.05220
#
# Epoch 00146: val_loss did not improve from 0.05220
#
# Epoch 00147: val_loss did not improve from 0.05220
#
# Epoch 00148: val_loss did not improve from 0.05220
#
# Epoch 00149: val_loss did not improve from 0.05220
#
# Epoch 00150: val_loss did not improve from 0.05220
#
# Epoch 00151: val_loss did not improve from 0.05220
#
# Epoch 00152: val_loss did not improve from 0.05220
#
# Epoch 00153: val_loss did not improve from 0.05220
#
# Epoch 00154: val_loss did not improve from 0.05220
#
# Epoch 00155: val_loss did not improve from 0.05220
#
# Epoch 00156: val_loss did not improve from 0.05220
#
# Epoch 00157: val_loss did not improve from 0.05220
#
# Epoch 00158: val_loss did not improve from 0.05220
#
# Epoch 00159: val_loss did not improve from 0.05220
#
# Epoch 00160: val_loss did not improve from 0.05220
#
# Epoch 00161: val_loss did not improve from 0.05220
#
# Epoch 00162: val_loss did not improve from 0.05220
#
# Epoch 00163: val_loss did not improve from 0.05220
#
# Epoch 00164: val_loss did not improve from 0.05220
#
# Epoch 00165: val_loss did not improve from 0.05220
#
# Epoch 00166: val_loss did not improve from 0.05220
#
# Epoch 00167: val_loss improved from 0.05220 to 0.05173, saving model to ./model2/167-0.0517.hdf5
#
# Epoch 00168: val_loss did not improve from 0.05173
#
# Epoch 00169: val_loss did not improve from 0.05173
#
# Epoch 00170: val_loss did not improve from 0.05173
#
# Epoch 00171: val_loss improved from 0.05173 to 0.05022, saving model to ./model2/171-0.0502.hdf5
#
# Epoch 00172: val_loss did not improve from 0.05022
#
# Epoch 00173: val_loss did not improve from 0.05022
#
# Epoch 00174: val_loss did not improve from 0.05022
#
# Epoch 00175: val_loss did not improve from 0.05022
#
# Epoch 00176: val_loss did not improve from 0.05022
#
# Epoch 00177: val_loss did not improve from 0.05022
#
# Epoch 00178: val_loss did not improve from 0.05022
#
# Epoch 00179: val_loss did not improve from 0.05022
#
# Epoch 00180: val_loss did not improve from 0.05022
#
# Epoch 00181: val_loss did not improve from 0.05022
#
# Epoch 00182: val_loss did not improve from 0.05022
#
# Epoch 00183: val_loss did not improve from 0.05022
#
# Epoch 00184: val_loss did not improve from 0.05022
#
# Epoch 00185: val_loss did not improve from 0.05022
#
# Epoch 00186: val_loss did not improve from 0.05022
#
# Epoch 00187: val_loss did not improve from 0.05022
#
# Epoch 00188: val_loss did not improve from 0.05022
#
# Epoch 00189: val_loss did not improve from 0.05022
#
# Epoch 00190: val_loss did not improve from 0.05022
#
# Epoch 00191: val_loss did not improve from 0.05022
#
# Epoch 00192: val_loss did not improve from 0.05022
#
# Epoch 00193: val_loss did not improve from 0.05022
#
# Epoch 00194: val_loss did not improve from 0.05022
#
# Epoch 00195: val_loss did not improve from 0.05022
#
# Epoch 00196: val_loss did not improve from 0.05022
#
# Epoch 00197: val_loss did not improve from 0.05022
#
# Epoch 00198: val_loss did not improve from 0.05022
#
# Epoch 00199: val_loss did not improve from 0.05022
#
# Epoch 00200: val_loss did not improve from 0.05022
