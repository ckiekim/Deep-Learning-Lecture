# %% [markdown]
# # 베스트 모델 만들기 - 와인 사례
# ## 이진 분류
# ## 베스트 모델 업데이트하기 - 자동 중단

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint, EarlyStopping

import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# seed 값 설정
seed = 0
np.random.seed(seed)
tf.set_random_seed(seed)

# %%
# 데이터 입력
df_pre = pd.read_csv('../dataset/wine.csv', header=None)
df = df_pre.sample(frac=0.15)
dataset = df.values
X = dataset[:,0:12]
Y = dataset[:,12]

# %%
# 모델 설정
model = Sequential() 
model.add(Dense(30, input_dim=12, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
# 모델 컴파일 
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
import os
# 모델 저장 폴더 만들기
MODEL_DIR = './model4/'
if not os.path.exists(MODEL_DIR):
    os.mkdir(MODEL_DIR)

modelpath="./model4/{epoch:02d}-{val_loss:.4f}.hdf5"

# %%
# 모델 업데이트 및 저장
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', 
                               verbose=1, save_best_only=True)

# %%
# 자동 중단 설정
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=100)

# %%
# 모델 실행
model.fit(X, Y, validation_split=0.2, epochs=3500, batch_size=500, verbose=0, 
          callbacks=[early_stopping_callback, checkpointer])
# Out:
# W0812 11:41:46.124879  4416 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Epoch 00001: val_loss improved from inf to 0.96954, saving model to ./model4/01-0.9695.hdf5
#
# Epoch 00002: val_loss improved from 0.96954 to 0.64378, saving model to ./model4/02-0.6438.hdf5
#
# Epoch 00003: val_loss improved from 0.64378 to 0.40085, saving model to ./model4/03-0.4008.hdf5
#
# Epoch 00004: val_loss improved from 0.40085 to 0.33617, saving model to ./model4/04-0.3362.hdf5
#
# Epoch 00005: val_loss did not improve from 0.33617
#
# Epoch 00006: val_loss did not improve from 0.33617
#
# Epoch 00007: val_loss improved from 0.33617 to 0.32555, saving model to ./model4/07-0.3256.hdf5
#
# Epoch 00008: val_loss improved from 0.32555 to 0.29631, saving model to ./model4/08-0.2963.hdf5
#
# Epoch 00009: val_loss did not improve from 0.29631
#
# Epoch 00010: val_loss did not improve from 0.29631
#
# Epoch 00011: val_loss did not improve from 0.29631
#
# Epoch 00012: val_loss did not improve from 0.29631
#
# Epoch 00013: val_loss did not improve from 0.29631
#
# Epoch 00014: val_loss improved from 0.29631 to 0.27117, saving model to ./model4/14-0.2712.hdf5
#
# Epoch 00015: val_loss improved from 0.27117 to 0.25834, saving model to ./model4/15-0.2583.hdf5
#
# Epoch 00016: val_loss improved from 0.25834 to 0.25603, saving model to ./model4/16-0.2560.hdf5
#
# Epoch 00017: val_loss improved from 0.25603 to 0.25134, saving model to ./model4/17-0.2513.hdf5
#
# Epoch 00018: val_loss improved from 0.25134 to 0.25072, saving model to ./model4/18-0.2507.hdf5
#
# Epoch 00019: val_loss did not improve from 0.25072
#
# Epoch 00020: val_loss did not improve from 0.25072
#
# Epoch 00021: val_loss did not improve from 0.25072
#
# Epoch 00022: val_loss did not improve from 0.25072
#
# Epoch 00023: val_loss did not improve from 0.25072
#
# Epoch 00024: val_loss improved from 0.25072 to 0.24613, saving model to ./model4/24-0.2461.hdf5
#
# Epoch 00025: val_loss improved from 0.24613 to 0.24110, saving model to ./model4/25-0.2411.hdf5
#
# Epoch 00026: val_loss improved from 0.24110 to 0.23812, saving model to ./model4/26-0.2381.hdf5
#
# Epoch 00027: val_loss improved from 0.23812 to 0.23723, saving model to ./model4/27-0.2372.hdf5
#
# Epoch 00028: val_loss did not improve from 0.23723
#
# Epoch 00029: val_loss did not improve from 0.23723
#
# Epoch 00030: val_loss did not improve from 0.23723
#
# Epoch 00031: val_loss did not improve from 0.23723
#
# Epoch 00032: val_loss did not improve from 0.23723
#
# Epoch 00033: val_loss did not improve from 0.23723
#
# Epoch 00034: val_loss did not improve from 0.23723
#
# Epoch 00035: val_loss did not improve from 0.23723
#
# Epoch 00036: val_loss improved from 0.23723 to 0.23527, saving model to ./model4/36-0.2353.hdf5
#
# Epoch 00037: val_loss improved from 0.23527 to 0.23408, saving model to ./model4/37-0.2341.hdf5
#
# Epoch 00038: val_loss did not improve from 0.23408
#
# Epoch 00039: val_loss did not improve from 0.23408
#
# Epoch 00040: val_loss did not improve from 0.23408
#
# Epoch 00041: val_loss did not improve from 0.23408
#
# Epoch 00042: val_loss did not improve from 0.23408
#
# Epoch 00043: val_loss improved from 0.23408 to 0.23068, saving model to ./model4/43-0.2307.hdf5
#
# Epoch 00044: val_loss improved from 0.23068 to 0.22894, saving model to ./model4/44-0.2289.hdf5
#
# Epoch 00045: val_loss improved from 0.22894 to 0.22838, saving model to ./model4/45-0.2284.hdf5
#
# Epoch 00046: val_loss did not improve from 0.22838
#
# Epoch 00047: val_loss did not improve from 0.22838
#
# Epoch 00048: val_loss did not improve from 0.22838
#
# Epoch 00049: val_loss did not improve from 0.22838
#
# Epoch 00050: val_loss improved from 0.22838 to 0.22837, saving model to ./model4/50-0.2284.hdf5
#
# Epoch 00051: val_loss improved from 0.22837 to 0.22543, saving model to ./model4/51-0.2254.hdf5
#
# Epoch 00052: val_loss improved from 0.22543 to 0.22215, saving model to ./model4/52-0.2222.hdf5
#
# Epoch 00053: val_loss improved from 0.22215 to 0.22204, saving model to ./model4/53-0.2220.hdf5
#
# Epoch 00054: val_loss did not improve from 0.22204
#
# Epoch 00055: val_loss did not improve from 0.22204
#
# Epoch 00056: val_loss did not improve from 0.22204
#
# Epoch 00057: val_loss did not improve from 0.22204
#
# Epoch 00058: val_loss improved from 0.22204 to 0.22127, saving model to ./model4/58-0.2213.hdf5
#
# Epoch 00059: val_loss improved from 0.22127 to 0.21838, saving model to ./model4/59-0.2184.hdf5
#
# Epoch 00060: val_loss did not improve from 0.21838
#
# Epoch 00061: val_loss did not improve from 0.21838
#
# Epoch 00062: val_loss did not improve from 0.21838
#
# Epoch 00063: val_loss did not improve from 0.21838
#
# Epoch 00064: val_loss did not improve from 0.21838
#
# Epoch 00065: val_loss improved from 0.21838 to 0.21705, saving model to ./model4/65-0.2170.hdf5
#
# Epoch 00066: val_loss improved from 0.21705 to 0.21643, saving model to ./model4/66-0.2164.hdf5
#
# Epoch 00067: val_loss did not improve from 0.21643
#
# Epoch 00068: val_loss did not improve from 0.21643
#
# Epoch 00069: val_loss did not improve from 0.21643
#
# Epoch 00070: val_loss did not improve from 0.21643
#
# Epoch 00071: val_loss did not improve from 0.21643
#
# Epoch 00072: val_loss did not improve from 0.21643
#
# Epoch 00073: val_loss improved from 0.21643 to 0.21633, saving model to ./model4/73-0.2163.hdf5
#
# Epoch 00074: val_loss improved from 0.21633 to 0.21577, saving model to ./model4/74-0.2158.hdf5
#
# Epoch 00075: val_loss improved from 0.21577 to 0.21350, saving model to ./model4/75-0.2135.hdf5
#
# Epoch 00076: val_loss improved from 0.21350 to 0.21231, saving model to ./model4/76-0.2123.hdf5
#
# Epoch 00077: val_loss improved from 0.21231 to 0.21227, saving model to ./model4/77-0.2123.hdf5
#
# Epoch 00078: val_loss did not improve from 0.21227
#
# Epoch 00079: val_loss did not improve from 0.21227
#
# Epoch 00080: val_loss did not improve from 0.21227
#
# Epoch 00081: val_loss did not improve from 0.21227
#
# Epoch 00082: val_loss improved from 0.21227 to 0.21038, saving model to ./model4/82-0.2104.hdf5
#
# Epoch 00083: val_loss improved from 0.21038 to 0.20916, saving model to ./model4/83-0.2092.hdf5
#
# Epoch 00084: val_loss did not improve from 0.20916
#
# Epoch 00085: val_loss did not improve from 0.20916
#
# Epoch 00086: val_loss did not improve from 0.20916
#
# Epoch 00087: val_loss did not improve from 0.20916
#
# Epoch 00088: val_loss did not improve from 0.20916
#
# Epoch 00089: val_loss improved from 0.20916 to 0.20884, saving model to ./model4/89-0.2088.hdf5
#
# Epoch 00090: val_loss improved from 0.20884 to 0.20757, saving model to ./model4/90-0.2076.hdf5
#
# Epoch 00091: val_loss improved from 0.20757 to 0.20651, saving model to ./model4/91-0.2065.hdf5
#
# Epoch 00092: val_loss did not improve from 0.20651
#
# Epoch 00093: val_loss did not improve from 0.20651
#
# Epoch 00094: val_loss did not improve from 0.20651
#
# Epoch 00095: val_loss did not improve from 0.20651
#
# Epoch 00096: val_loss improved from 0.20651 to 0.20576, saving model to ./model4/96-0.2058.hdf5
#
# Epoch 00097: val_loss improved from 0.20576 to 0.20495, saving model to ./model4/97-0.2050.hdf5
#
# Epoch 00098: val_loss did not improve from 0.20495
#
# Epoch 00099: val_loss did not improve from 0.20495
#
# Epoch 00100: val_loss improved from 0.20495 to 0.20351, saving model to ./model4/100-0.2035.hdf5
#
# Epoch 00101: val_loss improved from 0.20351 to 0.20259, saving model to ./model4/101-0.2026.hdf5
#
# Epoch 00102: val_loss did not improve from 0.20259
#
# Epoch 00103: val_loss did not improve from 0.20259
#
# Epoch 00104: val_loss did not improve from 0.20259
#
# Epoch 00105: val_loss did not improve from 0.20259
#
# Epoch 00106: val_loss improved from 0.20259 to 0.20198, saving model to ./model4/106-0.2020.hdf5
#
# Epoch 00107: val_loss improved from 0.20198 to 0.19895, saving model to ./model4/107-0.1989.hdf5
#
# Epoch 00108: val_loss improved from 0.19895 to 0.19878, saving model to ./model4/108-0.1988.hdf5
#
# Epoch 00109: val_loss did not improve from 0.19878
#
# Epoch 00110: val_loss did not improve from 0.19878
#
# Epoch 00111: val_loss did not improve from 0.19878
#
# Epoch 00112: val_loss did not improve from 0.19878
#
# Epoch 00113: val_loss improved from 0.19878 to 0.19844, saving model to ./model4/113-0.1984.hdf5
#
# Epoch 00114: val_loss improved from 0.19844 to 0.19712, saving model to ./model4/114-0.1971.hdf5
#
# Epoch 00115: val_loss did not improve from 0.19712
#
# Epoch 00116: val_loss did not improve from 0.19712
#
# Epoch 00117: val_loss did not improve from 0.19712
#
# Epoch 00118: val_loss improved from 0.19712 to 0.19533, saving model to ./model4/118-0.1953.hdf5
#
# Epoch 00119: val_loss improved from 0.19533 to 0.19201, saving model to ./model4/119-0.1920.hdf5
#
# Epoch 00120: val_loss improved from 0.19201 to 0.19028, saving model to ./model4/120-0.1903.hdf5
# Epoch 00121: val_loss did not improve from 0.19028
#
# Epoch 00122: val_loss did not improve from 0.19028
#
# Epoch 00123: val_loss did not improve from 0.19028
#
# Epoch 00124: val_loss improved from 0.19028 to 0.18668, saving model to ./model4/124-0.1867.hdf5
#
# Epoch 00125: val_loss did not improve from 0.18668
#
# Epoch 00126: val_loss did not improve from 0.18668
#
# Epoch 00127: val_loss did not improve from 0.18668
#
# Epoch 00128: val_loss did not improve from 0.18668
#
# Epoch 00129: val_loss improved from 0.18668 to 0.18431, saving model to ./model4/129-0.1843.hdf5
#
# Epoch 00130: val_loss did not improve from 0.18431
#
# Epoch 00131: val_loss did not improve from 0.18431
#
# Epoch 00132: val_loss did not improve from 0.18431
#
# Epoch 00133: val_loss did not improve from 0.18431
#
# Epoch 00134: val_loss improved from 0.18431 to 0.18416, saving model to ./model4/134-0.1842.hdf5
#
# Epoch 00135: val_loss did not improve from 0.18416
#
# Epoch 00136: val_loss did not improve from 0.18416
#
# Epoch 00137: val_loss did not improve from 0.18416
#
# Epoch 00138: val_loss improved from 0.18416 to 0.18256, saving model to ./model4/138-0.1826.hdf5
#
# Epoch 00139: val_loss improved from 0.18256 to 0.17993, saving model to ./model4/139-0.1799.hdf5
#
# Epoch 00140: val_loss did not improve from 0.17993
#
# Epoch 00141: val_loss did not improve from 0.17993
#
# Epoch 00142: val_loss did not improve from 0.17993
#
# Epoch 00143: val_loss improved from 0.17993 to 0.17893, saving model to ./model4/143-0.1789.hdf5
#
# Epoch 00144: val_loss improved from 0.17893 to 0.17590, saving model to ./model4/144-0.1759.hdf5
#
# Epoch 00145: val_loss did not improve from 0.17590
#
# Epoch 00146: val_loss did not improve from 0.17590
#
# Epoch 00147: val_loss did not improve from 0.17590
#
# Epoch 00148: val_loss did not improve from 0.17590
#
# Epoch 00149: val_loss improved from 0.17590 to 0.17372, saving model to ./model4/149-0.1737.hdf5
#
# Epoch 00150: val_loss did not improve from 0.17372
#
# Epoch 00151: val_loss did not improve from 0.17372
#
# Epoch 00152: val_loss did not improve from 0.17372
#
# Epoch 00153: val_loss improved from 0.17372 to 0.17273, saving model to ./model4/153-0.1727.hdf5
#
# Epoch 00154: val_loss improved from 0.17273 to 0.17074, saving model to ./model4/154-0.1707.hdf5
#
# Epoch 00155: val_loss did not improve from 0.17074
#
# Epoch 00156: val_loss did not improve from 0.17074
#
# Epoch 00157: val_loss did not improve from 0.17074
#
# Epoch 00158: val_loss did not improve from 0.17074
#
# Epoch 00159: val_loss improved from 0.17074 to 0.16768, saving model to ./model4/159-0.1677.hdf5
#
# Epoch 00160: val_loss improved from 0.16768 to 0.16536, saving model to ./model4/160-0.1654.hdf5
#
# Epoch 00161: val_loss did not improve from 0.16536
#
# Epoch 00162: val_loss did not improve from 0.16536
#
# Epoch 00163: val_loss improved from 0.16536 to 0.16535, saving model to ./model4/163-0.1653.hdf5
#
# Epoch 00164: val_loss improved from 0.16535 to 0.16082, saving model to ./model4/164-0.1608.hdf5
#
# Epoch 00165: val_loss did not improve from 0.16082
#
# Epoch 00166: val_loss did not improve from 0.16082
#
# Epoch 00167: val_loss did not improve from 0.16082
#
# Epoch 00168: val_loss improved from 0.16082 to 0.15904, saving model to ./model4/168-0.1590.hdf5
#
# Epoch 00169: val_loss did not improve from 0.15904
#
# Epoch 00170: val_loss did not improve from 0.15904
#
# Epoch 00171: val_loss did not improve from 0.15904
#
# Epoch 00172: val_loss improved from 0.15904 to 0.15658, saving model to ./model4/172-0.1566.hdf5
#
# Epoch 00173: val_loss did not improve from 0.15658
#
# Epoch 00174: val_loss did not improve from 0.15658
#
# Epoch 00175: val_loss did not improve from 0.15658
#
# Epoch 00176: val_loss improved from 0.15658 to 0.15375, saving model to ./model4/176-0.1538.hdf5
#
# Epoch 00177: val_loss did not improve from 0.15375
#
# Epoch 00178: val_loss did not improve from 0.15375
#
# Epoch 00179: val_loss did not improve from 0.15375
#
# Epoch 00180: val_loss improved from 0.15375 to 0.14990, saving model to ./model4/180-0.1499.hdf5
#
# Epoch 00181: val_loss did not improve from 0.14990
#
# Epoch 00182: val_loss did not improve from 0.14990
#
# Epoch 00183: val_loss did not improve from 0.14990
#
# Epoch 00184: val_loss improved from 0.14990 to 0.14669, saving model to ./model4/184-0.1467.hdf5
#
# Epoch 00185: val_loss did not improve from 0.14669
#
# Epoch 00186: val_loss did not improve from 0.14669
#
# Epoch 00187: val_loss did not improve from 0.14669
#
# Epoch 00188: val_loss improved from 0.14669 to 0.14306, saving model to ./model4/188-0.1431.hdf5
#
# Epoch 00189: val_loss did not improve from 0.14306
#
# Epoch 00190: val_loss did not improve from 0.14306
#
# Epoch 00191: val_loss did not improve from 0.14306
#
# Epoch 00192: val_loss improved from 0.14306 to 0.13991, saving model to ./model4/192-0.1399.hdf5
#
# Epoch 00193: val_loss did not improve from 0.13991
#
# Epoch 00194: val_loss did not improve from 0.13991
#
# Epoch 00195: val_loss improved from 0.13991 to 0.13968, saving model to ./model4/195-0.1397.hdf5
#
# Epoch 00196: val_loss improved from 0.13968 to 0.13830, saving model to ./model4/196-0.1383.hdf5
#
# Epoch 00197: val_loss did not improve from 0.13830
#
# Epoch 00198: val_loss did not improve from 0.13830
#
# Epoch 00199: val_loss did not improve from 0.13830
#
# Epoch 00200: val_loss improved from 0.13830 to 0.13732, saving model to ./model4/200-0.1373.hdf5
#
# Epoch 00201: val_loss improved from 0.13732 to 0.13624, saving model to ./model4/201-0.1362.hdf5
#
# Epoch 00202: val_loss did not improve from 0.13624
#
# Epoch 00203: val_loss did not improve from 0.13624
#
# Epoch 00204: val_loss did not improve from 0.13624
#
# Epoch 00205: val_loss improved from 0.13624 to 0.13342, saving model to ./model4/205-0.1334.hdf5
#
# Epoch 00206: val_loss did not improve from 0.13342
#
# Epoch 00207: val_loss improved from 0.13342 to 0.13250, saving model to ./model4/207-0.1325.hdf5
#
# Epoch 00208: val_loss did not improve from 0.13250
#
# Epoch 00209: val_loss did not improve from 0.13250
#
# Epoch 00210: val_loss did not improve from 0.13250
#
# Epoch 00211: val_loss improved from 0.13250 to 0.12913, saving model to ./model4/211-0.1291.hdf5
#
# Epoch 00212: val_loss did not improve from 0.12913
#
# Epoch 00213: val_loss did not improve from 0.12913
#
# Epoch 00214: val_loss did not improve from 0.12913
#
# Epoch 00215: val_loss improved from 0.12913 to 0.12842, saving model to ./model4/215-0.1284.hdf5
#
# Epoch 00216: val_loss improved from 0.12842 to 0.12801, saving model to ./model4/216-0.1280.hdf5
#
# Epoch 00217: val_loss did not improve from 0.12801
#
# Epoch 00218: val_loss improved from 0.12801 to 0.12640, saving model to ./model4/218-0.1264.hdf5
#
# Epoch 00219: val_loss improved from 0.12640 to 0.12577, saving model to ./model4/219-0.1258.hdf5
#
# Epoch 00220: val_loss did not improve from 0.12577
#
# Epoch 00221: val_loss did not improve from 0.12577
#
# Epoch 00222: val_loss did not improve from 0.12577
#
# Epoch 00223: val_loss did not improve from 0.12577
#
# Epoch 00224: val_loss did not improve from 0.12577
#
# Epoch 00225: val_loss did not improve from 0.12577
#
# Epoch 00226: val_loss did not improve from 0.12577
#
# Epoch 00227: val_loss did not improve from 0.12577
#
# Epoch 00228: val_loss did not improve from 0.12577
#
# Epoch 00229: val_loss did not improve from 0.12577
#
# Epoch 00230: val_loss improved from 0.12577 to 0.12279, saving model to ./model4/230-0.1228.hdf5
#
# Epoch 00231: val_loss did not improve from 0.12279
#
# Epoch 00232: val_loss did not improve from 0.12279
#
# Epoch 00233: val_loss improved from 0.12279 to 0.12126, saving model to ./model4/233-0.1213.hdf5
#
# Epoch 00234: val_loss did not improve from 0.12126
#
# Epoch 00235: val_loss did not improve from 0.12126
#
# Epoch 00236: val_loss did not improve from 0.12126
#
# Epoch 00237: val_loss did not improve from 0.12126
#
# Epoch 00238: val_loss did not improve from 0.12126
#
# Epoch 00239: val_loss did not improve from 0.12126
#
# Epoch 00240: val_loss improved from 0.12126 to 0.11736, saving model to ./model4/240-0.1174.hdf5
#
# Epoch 00241: val_loss did not improve from 0.11736
#
# Epoch 00242: val_loss did not improve from 0.11736
#
# Epoch 00243: val_loss did not improve from 0.11736
#
# Epoch 00244: val_loss did not improve from 0.11736
#
# Epoch 00245: val_loss did not improve from 0.11736
#
# Epoch 00246: val_loss did not improve from 0.11736
#
# Epoch 00247: val_loss did not improve from 0.11736
#
# Epoch 00248: val_loss did not improve from 0.11736
#
# Epoch 00249: val_loss improved from 0.11736 to 0.11736, saving model to ./model4/249-0.1174.hdf5
#
# Epoch 00250: val_loss did not improve from 0.11736
#
# Epoch 00251: val_loss did not improve from 0.11736
#
# Epoch 00252: val_loss improved from 0.11736 to 0.11401, saving model to ./model4/252-0.1140.hdf5
#
# Epoch 00253: val_loss did not improve from 0.11401
#
# Epoch 00254: val_loss did not improve from 0.11401
#
# Epoch 00255: val_loss improved from 0.11401 to 0.11086, saving model to ./model4/255-0.1109.hdf5
#
# Epoch 00256: val_loss did not improve from 0.11086
#
# Epoch 00257: val_loss did not improve from 0.11086
# Epoch 00258: val_loss improved from 0.11086 to 0.11067, saving model to ./model4/258-0.1107.hdf5
#
# Epoch 00259: val_loss did not improve from 0.11067
#
# Epoch 00260: val_loss did not improve from 0.11067
#
# Epoch 00261: val_loss improved from 0.11067 to 0.10895, saving model to ./model4/261-0.1090.hdf5
#
# Epoch 00262: val_loss did not improve from 0.10895
#
# Epoch 00263: val_loss did not improve from 0.10895
#
# Epoch 00264: val_loss did not improve from 0.10895
#
# Epoch 00265: val_loss did not improve from 0.10895
#
# Epoch 00266: val_loss did not improve from 0.10895
#
# Epoch 00267: val_loss did not improve from 0.10895
#
# Epoch 00268: val_loss improved from 0.10895 to 0.10599, saving model to ./model4/268-0.1060.hdf5
#
# Epoch 00269: val_loss did not improve from 0.10599
#
# Epoch 00270: val_loss did not improve from 0.10599
#
# Epoch 00271: val_loss did not improve from 0.10599
#
# Epoch 00272: val_loss did not improve from 0.10599
#
# Epoch 00273: val_loss did not improve from 0.10599
#
# Epoch 00274: val_loss improved from 0.10599 to 0.10469, saving model to ./model4/274-0.1047.hdf5
#
# Epoch 00275: val_loss did not improve from 0.10469
#
# Epoch 00276: val_loss did not improve from 0.10469
#
# Epoch 00277: val_loss did not improve from 0.10469
#
# Epoch 00278: val_loss improved from 0.10469 to 0.10371, saving model to ./model4/278-0.1037.hdf5
#
# Epoch 00279: val_loss did not improve from 0.10371
#
# Epoch 00280: val_loss did not improve from 0.10371
#
# Epoch 00281: val_loss did not improve from 0.10371
#
# Epoch 00282: val_loss did not improve from 0.10371
#
# Epoch 00283: val_loss did not improve from 0.10371
#
# Epoch 00284: val_loss improved from 0.10371 to 0.10198, saving model to ./model4/284-0.1020.hdf5
#
# Epoch 00285: val_loss did not improve from 0.10198
#
# Epoch 00286: val_loss did not improve from 0.10198
#
# Epoch 00287: val_loss improved from 0.10198 to 0.10169, saving model to ./model4/287-0.1017.hdf5
#
# Epoch 00288: val_loss did not improve from 0.10169
#
# Epoch 00289: val_loss did not improve from 0.10169
#
# Epoch 00290: val_loss did not improve from 0.10169
#
# Epoch 00291: val_loss did not improve from 0.10169
#
# Epoch 00292: val_loss improved from 0.10169 to 0.10074, saving model to ./model4/292-0.1007.hdf5
#
# Epoch 00293: val_loss did not improve from 0.10074
#
# Epoch 00294: val_loss improved from 0.10074 to 0.09936, saving model to ./model4/294-0.0994.hdf5
#
# Epoch 00295: val_loss improved from 0.09936 to 0.09861, saving model to ./model4/295-0.0986.hdf5
#
# Epoch 00296: val_loss did not improve from 0.09861
#
# Epoch 00297: val_loss did not improve from 0.09861
#
# Epoch 00298: val_loss improved from 0.09861 to 0.09633, saving model to ./model4/298-0.0963.hdf5
#
# Epoch 00299: val_loss did not improve from 0.09633
#
# Epoch 00300: val_loss did not improve from 0.09633
#
# Epoch 00301: val_loss did not improve from 0.09633
#
# Epoch 00302: val_loss did not improve from 0.09633
#
# Epoch 00303: val_loss did not improve from 0.09633
#
# Epoch 00304: val_loss did not improve from 0.09633
#
# Epoch 00305: val_loss did not improve from 0.09633
#
# Epoch 00306: val_loss did not improve from 0.09633
#
# Epoch 00307: val_loss did not improve from 0.09633
#
# Epoch 00308: val_loss did not improve from 0.09633
#
# Epoch 00309: val_loss improved from 0.09633 to 0.09448, saving model to ./model4/309-0.0945.hdf5
#
# Epoch 00310: val_loss did not improve from 0.09448
#
# Epoch 00311: val_loss did not improve from 0.09448
#
# Epoch 00312: val_loss did not improve from 0.09448
#
# Epoch 00313: val_loss did not improve from 0.09448
#
# Epoch 00314: val_loss did not improve from 0.09448
#
# Epoch 00315: val_loss improved from 0.09448 to 0.09275, saving model to ./model4/315-0.0927.hdf5
#
# Epoch 00316: val_loss did not improve from 0.09275
#
# Epoch 00317: val_loss did not improve from 0.09275
#
# Epoch 00318: val_loss improved from 0.09275 to 0.09188, saving model to ./model4/318-0.0919.hdf5
#
# Epoch 00319: val_loss did not improve from 0.09188
#
# Epoch 00320: val_loss did not improve from 0.09188
#
# Epoch 00321: val_loss improved from 0.09188 to 0.08991, saving model to ./model4/321-0.0899.hdf5
#
# Epoch 00322: val_loss did not improve from 0.08991
#
# Epoch 00323: val_loss did not improve from 0.08991
#
# Epoch 00324: val_loss did not improve from 0.08991
#
# Epoch 00325: val_loss did not improve from 0.08991
#
# Epoch 00326: val_loss did not improve from 0.08991
#
# Epoch 00327: val_loss did not improve from 0.08991
#
# Epoch 00328: val_loss did not improve from 0.08991
#
# Epoch 00329: val_loss did not improve from 0.08991
#
# Epoch 00330: val_loss did not improve from 0.08991
#
# Epoch 00331: val_loss did not improve from 0.08991
#
# Epoch 00332: val_loss did not improve from 0.08991
#
# Epoch 00333: val_loss improved from 0.08991 to 0.08878, saving model to ./model4/333-0.0888.hdf5
#
# Epoch 00334: val_loss improved from 0.08878 to 0.08581, saving model to ./model4/334-0.0858.hdf5
#
# Epoch 00335: val_loss did not improve from 0.08581
#
# Epoch 00336: val_loss did not improve from 0.08581
#
# Epoch 00337: val_loss did not improve from 0.08581
#
# Epoch 00338: val_loss did not improve from 0.08581
#
# Epoch 00339: val_loss did not improve from 0.08581
#
# Epoch 00340: val_loss did not improve from 0.08581
#
# Epoch 00341: val_loss did not improve from 0.08581
#
# Epoch 00342: val_loss did not improve from 0.08581
#
# Epoch 00343: val_loss did not improve from 0.08581
#
# Epoch 00344: val_loss did not improve from 0.08581
#
# Epoch 00345: val_loss did not improve from 0.08581
#
# Epoch 00346: val_loss did not improve from 0.08581
#
# Epoch 00347: val_loss did not improve from 0.08581
#
# Epoch 00348: val_loss did not improve from 0.08581
#
# Epoch 00349: val_loss did not improve from 0.08581
#
# Epoch 00350: val_loss did not improve from 0.08581
#
# Epoch 00351: val_loss did not improve from 0.08581
#
# Epoch 00352: val_loss did not improve from 0.08581
#
# Epoch 00353: val_loss did not improve from 0.08581
#
# Epoch 00354: val_loss did not improve from 0.08581
#
# Epoch 00355: val_loss did not improve from 0.08581
#
# Epoch 00356: val_loss did not improve from 0.08581
#
# Epoch 00357: val_loss did not improve from 0.08581
#
# Epoch 00358: val_loss did not improve from 0.08581
#
# Epoch 00359: val_loss improved from 0.08581 to 0.08361, saving model to ./model4/359-0.0836.hdf5
#
# Epoch 00360: val_loss did not improve from 0.08361
#
# Epoch 00361: val_loss improved from 0.08361 to 0.08356, saving model to ./model4/361-0.0836.hdf5
#
# Epoch 00362: val_loss did not improve from 0.08356
#
# Epoch 00363: val_loss did not improve from 0.08356
#
# Epoch 00364: val_loss did not improve from 0.08356
#
# Epoch 00365: val_loss did not improve from 0.08356
#
# Epoch 00366: val_loss did not improve from 0.08356
#
# Epoch 00367: val_loss did not improve from 0.08356
#
# Epoch 00368: val_loss improved from 0.08356 to 0.08262, saving model to ./model4/368-0.0826.hdf5
#
# Epoch 00369: val_loss did not improve from 0.08262
#
# Epoch 00370: val_loss did not improve from 0.08262
#
# Epoch 00371: val_loss did not improve from 0.08262
#
# Epoch 00372: val_loss did not improve from 0.08262
#
# Epoch 00373: val_loss improved from 0.08262 to 0.08045, saving model to ./model4/373-0.0805.hdf5
#
# Epoch 00374: val_loss did not improve from 0.08045
#
# Epoch 00375: val_loss did not improve from 0.08045
#
# Epoch 00376: val_loss improved from 0.08045 to 0.07991, saving model to ./model4/376-0.0799.hdf5
#
# Epoch 00377: val_loss did not improve from 0.07991
#
# Epoch 00378: val_loss did not improve from 0.07991
#
# Epoch 00379: val_loss did not improve from 0.07991
#
# Epoch 00380: val_loss did not improve from 0.07991
#
# Epoch 00381: val_loss improved from 0.07991 to 0.07968, saving model to ./model4/381-0.0797.hdf5
#
# Epoch 00382: val_loss did not improve from 0.07968
#
# Epoch 00383: val_loss did not improve from 0.07968
#
# Epoch 00384: val_loss did not improve from 0.07968
#
# Epoch 00385: val_loss did not improve from 0.07968
#
# Epoch 00386: val_loss did not improve from 0.07968
#
# Epoch 00387: val_loss did not improve from 0.07968
#
# Epoch 00388: val_loss did not improve from 0.07968
#
# Epoch 00389: val_loss did not improve from 0.07968
#
# Epoch 00390: val_loss improved from 0.07968 to 0.07835, saving model to ./model4/390-0.0783.hdf5
#
# Epoch 00391: val_loss did not improve from 0.07835
#
# Epoch 00392: val_loss did not improve from 0.07835
#
# Epoch 00393: val_loss improved from 0.07835 to 0.07803, saving model to ./model4/393-0.0780.hdf5
#
# Epoch 00394: val_loss did not improve from 0.07803
#
# Epoch 00395: val_loss did not improve from 0.07803
#
# Epoch 00396: val_loss improved from 0.07803 to 0.07673, saving model to ./model4/396-0.0767.hdf5
#
# Epoch 00397: val_loss did not improve from 0.07673
#
# Epoch 00398: val_loss did not improve from 0.07673
#
# Epoch 00399: val_loss did not improve from 0.07673
#
# Epoch 00400: val_loss did not improve from 0.07673
#
# Epoch 00401: val_loss did not improve from 0.07673
#
# Epoch 00402: val_loss improved from 0.07673 to 0.07632, saving model to ./model4/402-0.0763.hdf5
#
# Epoch 00403: val_loss improved from 0.07632 to 0.07579, saving model to ./model4/403-0.0758.hdf5
# Epoch 00404: val_loss did not improve from 0.07579
#
# Epoch 00405: val_loss did not improve from 0.07579
#
# Epoch 00406: val_loss did not improve from 0.07579
#
# Epoch 00407: val_loss did not improve from 0.07579
#
# Epoch 00408: val_loss did not improve from 0.07579
#
# Epoch 00409: val_loss did not improve from 0.07579
#
# Epoch 00410: val_loss did not improve from 0.07579
#
# Epoch 00411: val_loss did not improve from 0.07579
#
# Epoch 00412: val_loss improved from 0.07579 to 0.07432, saving model to ./model4/412-0.0743.hdf5
#
# Epoch 00413: val_loss improved from 0.07432 to 0.07298, saving model to ./model4/413-0.0730.hdf5
#
# Epoch 00414: val_loss did not improve from 0.07298
#
# Epoch 00415: val_loss did not improve from 0.07298
#
# Epoch 00416: val_loss did not improve from 0.07298
#
# Epoch 00417: val_loss did not improve from 0.07298
#
# Epoch 00418: val_loss did not improve from 0.07298
#
# Epoch 00419: val_loss did not improve from 0.07298
#
# Epoch 00420: val_loss did not improve from 0.07298
#
# Epoch 00421: val_loss did not improve from 0.07298
#
# Epoch 00422: val_loss did not improve from 0.07298
#
# Epoch 00423: val_loss did not improve from 0.07298
#
# Epoch 00424: val_loss did not improve from 0.07298
#
# Epoch 00425: val_loss did not improve from 0.07298
#
# Epoch 00426: val_loss did not improve from 0.07298
#
# Epoch 00427: val_loss did not improve from 0.07298
#
# Epoch 00428: val_loss did not improve from 0.07298
#
# Epoch 00429: val_loss did not improve from 0.07298
#
# Epoch 00430: val_loss did not improve from 0.07298
#
# Epoch 00431: val_loss did not improve from 0.07298
#
# Epoch 00432: val_loss improved from 0.07298 to 0.06923, saving model to ./model4/432-0.0692.hdf5
#
# Epoch 00433: val_loss did not improve from 0.06923
#
# Epoch 00434: val_loss did not improve from 0.06923
#
# Epoch 00435: val_loss did not improve from 0.06923
#
# Epoch 00436: val_loss did not improve from 0.06923
#
# Epoch 00437: val_loss did not improve from 0.06923
#
# Epoch 00438: val_loss did not improve from 0.06923
#
# Epoch 00439: val_loss did not improve from 0.06923
#
# Epoch 00440: val_loss did not improve from 0.06923
#
# Epoch 00441: val_loss did not improve from 0.06923
#
# Epoch 00442: val_loss did not improve from 0.06923
#
# Epoch 00443: val_loss did not improve from 0.06923
#
# Epoch 00444: val_loss did not improve from 0.06923
#
# Epoch 00445: val_loss did not improve from 0.06923
#
# Epoch 00446: val_loss did not improve from 0.06923
#
# Epoch 00447: val_loss did not improve from 0.06923
#
# Epoch 00448: val_loss did not improve from 0.06923
#
# Epoch 00449: val_loss did not improve from 0.06923
#
# Epoch 00450: val_loss did not improve from 0.06923
#
# Epoch 00451: val_loss improved from 0.06923 to 0.06895, saving model to ./model4/451-0.0690.hdf5
#
# Epoch 00452: val_loss did not improve from 0.06895
#
# Epoch 00453: val_loss did not improve from 0.06895
#
# Epoch 00454: val_loss improved from 0.06895 to 0.06860, saving model to ./model4/454-0.0686.hdf5
#
# Epoch 00455: val_loss did not improve from 0.06860
#
# Epoch 00456: val_loss did not improve from 0.06860
#
# Epoch 00457: val_loss did not improve from 0.06860
#
# Epoch 00458: val_loss did not improve from 0.06860
#
# Epoch 00459: val_loss did not improve from 0.06860
#
# Epoch 00460: val_loss did not improve from 0.06860
#
# Epoch 00461: val_loss improved from 0.06860 to 0.06787, saving model to ./model4/461-0.0679.hdf5
#
# Epoch 00462: val_loss did not improve from 0.06787
#
# Epoch 00463: val_loss did not improve from 0.06787
#
# Epoch 00464: val_loss did not improve from 0.06787
#
# Epoch 00465: val_loss did not improve from 0.06787
#
# Epoch 00466: val_loss did not improve from 0.06787
#
# Epoch 00467: val_loss improved from 0.06787 to 0.06650, saving model to ./model4/467-0.0665.hdf5
#
# Epoch 00468: val_loss did not improve from 0.06650
#
# Epoch 00469: val_loss did not improve from 0.06650
#
# Epoch 00470: val_loss improved from 0.06650 to 0.06606, saving model to ./model4/470-0.0661.hdf5
#
# Epoch 00471: val_loss did not improve from 0.06606
#
# Epoch 00472: val_loss did not improve from 0.06606
#
# Epoch 00473: val_loss did not improve from 0.06606
#
# Epoch 00474: val_loss did not improve from 0.06606
#
# Epoch 00475: val_loss did not improve from 0.06606
#
# Epoch 00476: val_loss did not improve from 0.06606
#
# Epoch 00477: val_loss did not improve from 0.06606
#
# Epoch 00478: val_loss did not improve from 0.06606
#
# Epoch 00479: val_loss improved from 0.06606 to 0.06510, saving model to ./model4/479-0.0651.hdf5
#
# Epoch 00480: val_loss did not improve from 0.06510
#
# Epoch 00481: val_loss did not improve from 0.06510
#
# Epoch 00482: val_loss did not improve from 0.06510
#
# Epoch 00483: val_loss did not improve from 0.06510
#
# Epoch 00484: val_loss did not improve from 0.06510
#
# Epoch 00485: val_loss did not improve from 0.06510
#
# Epoch 00486: val_loss did not improve from 0.06510
#
# Epoch 00487: val_loss did not improve from 0.06510
#
# Epoch 00488: val_loss did not improve from 0.06510
#
# Epoch 00489: val_loss did not improve from 0.06510
#
# Epoch 00490: val_loss did not improve from 0.06510
#
# Epoch 00491: val_loss did not improve from 0.06510
#
# Epoch 00492: val_loss improved from 0.06510 to 0.06369, saving model to ./model4/492-0.0637.hdf5
#
# Epoch 00493: val_loss did not improve from 0.06369
#
# Epoch 00494: val_loss did not improve from 0.06369
#
# Epoch 00495: val_loss did not improve from 0.06369
#
# Epoch 00496: val_loss did not improve from 0.06369
#
# Epoch 00497: val_loss did not improve from 0.06369
#
# Epoch 00498: val_loss did not improve from 0.06369
#
# Epoch 00499: val_loss did not improve from 0.06369
#
# Epoch 00500: val_loss did not improve from 0.06369
#
# Epoch 00501: val_loss did not improve from 0.06369
#
# Epoch 00502: val_loss did not improve from 0.06369
#
# Epoch 00503: val_loss did not improve from 0.06369
#
# Epoch 00504: val_loss did not improve from 0.06369
#
# Epoch 00505: val_loss did not improve from 0.06369
#
# Epoch 00506: val_loss did not improve from 0.06369
#
# Epoch 00507: val_loss did not improve from 0.06369
#
# Epoch 00508: val_loss did not improve from 0.06369
#
# Epoch 00509: val_loss did not improve from 0.06369
#
# Epoch 00510: val_loss did not improve from 0.06369
#
# Epoch 00511: val_loss did not improve from 0.06369
#
# Epoch 00512: val_loss did not improve from 0.06369
#
# Epoch 00513: val_loss did not improve from 0.06369
#
# Epoch 00514: val_loss did not improve from 0.06369
#
# Epoch 00515: val_loss did not improve from 0.06369
#
# Epoch 00516: val_loss did not improve from 0.06369
#
# Epoch 00517: val_loss did not improve from 0.06369
#
# Epoch 00518: val_loss did not improve from 0.06369
#
# Epoch 00519: val_loss improved from 0.06369 to 0.06284, saving model to ./model4/519-0.0628.hdf5
#
# Epoch 00520: val_loss did not improve from 0.06284
#
# Epoch 00521: val_loss did not improve from 0.06284
#
# Epoch 00522: val_loss did not improve from 0.06284
#
# Epoch 00523: val_loss did not improve from 0.06284
#
# Epoch 00524: val_loss did not improve from 0.06284
#
# Epoch 00525: val_loss did not improve from 0.06284
#
# Epoch 00526: val_loss did not improve from 0.06284
#
# Epoch 00527: val_loss did not improve from 0.06284
#
# Epoch 00528: val_loss did not improve from 0.06284
#
# Epoch 00529: val_loss improved from 0.06284 to 0.06255, saving model to ./model4/529-0.0625.hdf5
#
# Epoch 00530: val_loss did not improve from 0.06255
#
# Epoch 00531: val_loss did not improve from 0.06255
#
# Epoch 00532: val_loss improved from 0.06255 to 0.06187, saving model to ./model4/532-0.0619.hdf5
#
# Epoch 00533: val_loss did not improve from 0.06187
#
# Epoch 00534: val_loss did not improve from 0.06187
#
# Epoch 00535: val_loss did not improve from 0.06187
#
# Epoch 00536: val_loss did not improve from 0.06187
#
# Epoch 00537: val_loss did not improve from 0.06187
#
# Epoch 00538: val_loss did not improve from 0.06187
#
# Epoch 00539: val_loss did not improve from 0.06187
#
# Epoch 00540: val_loss did not improve from 0.06187
#
# Epoch 00541: val_loss did not improve from 0.06187
#
# Epoch 00542: val_loss did not improve from 0.06187
#
# Epoch 00543: val_loss did not improve from 0.06187
#
# Epoch 00544: val_loss did not improve from 0.06187
#
# Epoch 00545: val_loss did not improve from 0.06187
#
# Epoch 00546: val_loss did not improve from 0.06187
#
# Epoch 00547: val_loss did not improve from 0.06187
#
# Epoch 00548: val_loss did not improve from 0.06187
#
# Epoch 00549: val_loss did not improve from 0.06187
#
# Epoch 00550: val_loss did not improve from 0.06187
#
# Epoch 00551: val_loss did not improve from 0.06187
#
# Epoch 00552: val_loss did not improve from 0.06187
#
# Epoch 00553: val_loss improved from 0.06187 to 0.05888, saving model to ./model4/553-0.0589.hdf5
#
# Epoch 00554: val_loss did not improve from 0.05888
#
# Epoch 00555: val_loss did not improve from 0.05888
#
# Epoch 00556: val_loss did not improve from 0.05888
#
# Epoch 00557: val_loss did not improve from 0.05888
#
# Epoch 00558: val_loss did not improve from 0.05888
#
# Epoch 00559: val_loss did not improve from 0.05888
#
# Epoch 00560: val_loss did not improve from 0.05888
#
# Epoch 00561: val_loss did not improve from 0.05888
#
# Epoch 00562: val_loss did not improve from 0.05888
#
# Epoch 00563: val_loss did not improve from 0.05888
#
# Epoch 00564: val_loss did not improve from 0.05888
#
# Epoch 00565: val_loss did not improve from 0.05888
#
# Epoch 00566: val_loss did not improve from 0.05888
#
# Epoch 00567: val_loss did not improve from 0.05888
#
# Epoch 00568: val_loss did not improve from 0.05888
#
# Epoch 00569: val_loss did not improve from 0.05888
#
# Epoch 00570: val_loss improved from 0.05888 to 0.05617, saving model to ./model4/570-0.0562.hdf5
#
# Epoch 00571: val_loss did not improve from 0.05617
#
# Epoch 00572: val_loss did not improve from 0.05617
#
# Epoch 00573: val_loss did not improve from 0.05617
#
# Epoch 00574: val_loss did not improve from 0.05617
# Epoch 00575: val_loss did not improve from 0.05617
#
# Epoch 00576: val_loss did not improve from 0.05617
#
# Epoch 00577: val_loss did not improve from 0.05617
#
# Epoch 00578: val_loss did not improve from 0.05617
#
# Epoch 00579: val_loss did not improve from 0.05617
#
# Epoch 00580: val_loss did not improve from 0.05617
#
# Epoch 00581: val_loss did not improve from 0.05617
#
# Epoch 00582: val_loss did not improve from 0.05617
#
# Epoch 00583: val_loss did not improve from 0.05617
#
# Epoch 00584: val_loss did not improve from 0.05617
#
# Epoch 00585: val_loss did not improve from 0.05617
#
# Epoch 00586: val_loss improved from 0.05617 to 0.05528, saving model to ./model4/586-0.0553.hdf5
#
# Epoch 00587: val_loss did not improve from 0.05528
#
# Epoch 00588: val_loss did not improve from 0.05528
#
# Epoch 00589: val_loss did not improve from 0.05528
#
# Epoch 00590: val_loss did not improve from 0.05528
#
# Epoch 00591: val_loss did not improve from 0.05528
#
# Epoch 00592: val_loss did not improve from 0.05528
#
# Epoch 00593: val_loss did not improve from 0.05528
#
# Epoch 00594: val_loss did not improve from 0.05528
#
# Epoch 00595: val_loss did not improve from 0.05528
#
# Epoch 00596: val_loss did not improve from 0.05528
#
# Epoch 00597: val_loss did not improve from 0.05528
#
# Epoch 00598: val_loss did not improve from 0.05528
#
# Epoch 00599: val_loss did not improve from 0.05528
#
# Epoch 00600: val_loss did not improve from 0.05528
#
# Epoch 00601: val_loss did not improve from 0.05528
#
# Epoch 00602: val_loss did not improve from 0.05528
#
# Epoch 00603: val_loss did not improve from 0.05528
#
# Epoch 00604: val_loss did not improve from 0.05528
#
# Epoch 00605: val_loss did not improve from 0.05528
#
# Epoch 00606: val_loss did not improve from 0.05528
#
# Epoch 00607: val_loss did not improve from 0.05528
#
# Epoch 00608: val_loss did not improve from 0.05528
#
# Epoch 00609: val_loss did not improve from 0.05528
#
# Epoch 00610: val_loss did not improve from 0.05528
#
# Epoch 00611: val_loss did not improve from 0.05528
#
# Epoch 00612: val_loss did not improve from 0.05528
#
# Epoch 00613: val_loss did not improve from 0.05528
#
# Epoch 00614: val_loss did not improve from 0.05528
#
# Epoch 00615: val_loss did not improve from 0.05528
#
# Epoch 00616: val_loss did not improve from 0.05528
#
# Epoch 00617: val_loss did not improve from 0.05528
#
# Epoch 00618: val_loss did not improve from 0.05528
#
# Epoch 00619: val_loss did not improve from 0.05528
#
# Epoch 00620: val_loss did not improve from 0.05528
#
# Epoch 00621: val_loss did not improve from 0.05528
#
# Epoch 00622: val_loss did not improve from 0.05528
#
# Epoch 00623: val_loss did not improve from 0.05528
#
# Epoch 00624: val_loss did not improve from 0.05528
#
# Epoch 00625: val_loss did not improve from 0.05528
#
# Epoch 00626: val_loss did not improve from 0.05528
#
# Epoch 00627: val_loss did not improve from 0.05528
#
# Epoch 00628: val_loss did not improve from 0.05528
#
# Epoch 00629: val_loss did not improve from 0.05528
#
# Epoch 00630: val_loss did not improve from 0.05528
#
# Epoch 00631: val_loss did not improve from 0.05528
#
# Epoch 00632: val_loss did not improve from 0.05528
#
# Epoch 00633: val_loss did not improve from 0.05528
#
# Epoch 00634: val_loss did not improve from 0.05528
#
# Epoch 00635: val_loss did not improve from 0.05528
#
# Epoch 00636: val_loss did not improve from 0.05528
#
# Epoch 00637: val_loss did not improve from 0.05528
#
# Epoch 00638: val_loss did not improve from 0.05528
#
# Epoch 00639: val_loss did not improve from 0.05528
#
# Epoch 00640: val_loss did not improve from 0.05528
#
# Epoch 00641: val_loss did not improve from 0.05528
#
# Epoch 00642: val_loss did not improve from 0.05528
#
# Epoch 00643: val_loss did not improve from 0.05528
#
# Epoch 00644: val_loss did not improve from 0.05528
#
# Epoch 00645: val_loss did not improve from 0.05528
#
# Epoch 00646: val_loss did not improve from 0.05528
#
# Epoch 00647: val_loss did not improve from 0.05528
#
# Epoch 00648: val_loss did not improve from 0.05528
#
# Epoch 00649: val_loss did not improve from 0.05528
#
# Epoch 00650: val_loss did not improve from 0.05528
#
# Epoch 00651: val_loss improved from 0.05528 to 0.05192, saving model to ./model4/651-0.0519.hdf5
#
# Epoch 00652: val_loss did not improve from 0.05192
#
# Epoch 00653: val_loss did not improve from 0.05192
#
# Epoch 00654: val_loss did not improve from 0.05192
#
# Epoch 00655: val_loss did not improve from 0.05192
#
# Epoch 00656: val_loss did not improve from 0.05192
#
# Epoch 00657: val_loss did not improve from 0.05192
#
# Epoch 00658: val_loss did not improve from 0.05192
#
# Epoch 00659: val_loss did not improve from 0.05192
#
# Epoch 00660: val_loss did not improve from 0.05192
#
# Epoch 00661: val_loss did not improve from 0.05192
#
# Epoch 00662: val_loss did not improve from 0.05192
#
# Epoch 00663: val_loss did not improve from 0.05192
#
# Epoch 00664: val_loss did not improve from 0.05192
#
# Epoch 00665: val_loss did not improve from 0.05192
#
# Epoch 00666: val_loss did not improve from 0.05192
#
# Epoch 00667: val_loss did not improve from 0.05192
#
# Epoch 00668: val_loss did not improve from 0.05192
#
# Epoch 00669: val_loss did not improve from 0.05192
#
# Epoch 00670: val_loss did not improve from 0.05192
#
# Epoch 00671: val_loss did not improve from 0.05192
#
# Epoch 00672: val_loss did not improve from 0.05192
#
# Epoch 00673: val_loss did not improve from 0.05192
#
# Epoch 00674: val_loss did not improve from 0.05192
#
# Epoch 00675: val_loss did not improve from 0.05192
#
# Epoch 00676: val_loss did not improve from 0.05192
#
# Epoch 00677: val_loss did not improve from 0.05192
#
# Epoch 00678: val_loss did not improve from 0.05192
#
# Epoch 00679: val_loss improved from 0.05192 to 0.05045, saving model to ./model4/679-0.0505.hdf5
#
# Epoch 00680: val_loss did not improve from 0.05045
#
# Epoch 00681: val_loss did not improve from 0.05045
#
# Epoch 00682: val_loss did not improve from 0.05045
#
# Epoch 00683: val_loss did not improve from 0.05045
#
# Epoch 00684: val_loss did not improve from 0.05045
#
# Epoch 00685: val_loss did not improve from 0.05045
#
# Epoch 00686: val_loss did not improve from 0.05045
#
# Epoch 00687: val_loss did not improve from 0.05045
#
# Epoch 00688: val_loss did not improve from 0.05045
#
# Epoch 00689: val_loss did not improve from 0.05045
#
# Epoch 00690: val_loss did not improve from 0.05045
#
# Epoch 00691: val_loss did not improve from 0.05045
#
# Epoch 00692: val_loss did not improve from 0.05045
#
# Epoch 00693: val_loss did not improve from 0.05045
#
# Epoch 00694: val_loss did not improve from 0.05045
#
# Epoch 00695: val_loss did not improve from 0.05045
#
# Epoch 00696: val_loss did not improve from 0.05045
#
# Epoch 00697: val_loss did not improve from 0.05045
#
# Epoch 00698: val_loss did not improve from 0.05045
#
# Epoch 00699: val_loss did not improve from 0.05045
#
# Epoch 00700: val_loss did not improve from 0.05045
#
# Epoch 00701: val_loss did not improve from 0.05045
#
# Epoch 00702: val_loss did not improve from 0.05045
#
# Epoch 00703: val_loss did not improve from 0.05045
#
# Epoch 00704: val_loss did not improve from 0.05045
#
# Epoch 00705: val_loss did not improve from 0.05045
#
# Epoch 00706: val_loss did not improve from 0.05045
#
# Epoch 00707: val_loss did not improve from 0.05045
#
# Epoch 00708: val_loss did not improve from 0.05045
#
# Epoch 00709: val_loss did not improve from 0.05045
#
# Epoch 00710: val_loss did not improve from 0.05045
#
# Epoch 00711: val_loss did not improve from 0.05045
#
# Epoch 00712: val_loss did not improve from 0.05045
#
# Epoch 00713: val_loss did not improve from 0.05045
#
# Epoch 00714: val_loss did not improve from 0.05045
#
# Epoch 00715: val_loss did not improve from 0.05045
#
# Epoch 00716: val_loss did not improve from 0.05045
#
# Epoch 00717: val_loss did not improve from 0.05045
#
# Epoch 00718: val_loss did not improve from 0.05045
#
# Epoch 00719: val_loss did not improve from 0.05045
#
# Epoch 00720: val_loss did not improve from 0.05045
#
# Epoch 00721: val_loss did not improve from 0.05045
#
# Epoch 00722: val_loss did not improve from 0.05045
#
# Epoch 00723: val_loss did not improve from 0.05045
#
# Epoch 00724: val_loss did not improve from 0.05045
#
# Epoch 00725: val_loss did not improve from 0.05045
#
# Epoch 00726: val_loss did not improve from 0.05045
#
# Epoch 00727: val_loss did not improve from 0.05045
#
# Epoch 00728: val_loss did not improve from 0.05045
#
# Epoch 00729: val_loss did not improve from 0.05045
#
# Epoch 00730: val_loss did not improve from 0.05045
#
# Epoch 00731: val_loss did not improve from 0.05045
#
# Epoch 00732: val_loss did not improve from 0.05045
#
# Epoch 00733: val_loss did not improve from 0.05045
#
# Epoch 00734: val_loss did not improve from 0.05045
#
# Epoch 00735: val_loss did not improve from 0.05045
#
# Epoch 00736: val_loss did not improve from 0.05045
#
# Epoch 00737: val_loss did not improve from 0.05045
#
# Epoch 00738: val_loss did not improve from 0.05045
#
# Epoch 00739: val_loss did not improve from 0.05045
#
# Epoch 00740: val_loss did not improve from 0.05045
#
# Epoch 00741: val_loss did not improve from 0.05045
#
# Epoch 00742: val_loss did not improve from 0.05045
#
# Epoch 00743: val_loss did not improve from 0.05045
#
# Epoch 00744: val_loss did not improve from 0.05045
#
# Epoch 00745: val_loss did not improve from 0.05045
# Epoch 00746: val_loss did not improve from 0.05045
#
# Epoch 00747: val_loss did not improve from 0.05045
#
# Epoch 00748: val_loss did not improve from 0.05045
#
# Epoch 00749: val_loss did not improve from 0.05045
#
# Epoch 00750: val_loss did not improve from 0.05045
#
# Epoch 00751: val_loss did not improve from 0.05045
#
# Epoch 00752: val_loss did not improve from 0.05045
#
# Epoch 00753: val_loss did not improve from 0.05045
#
# Epoch 00754: val_loss did not improve from 0.05045
#
# Epoch 00755: val_loss did not improve from 0.05045
#
# Epoch 00756: val_loss did not improve from 0.05045
#
# Epoch 00757: val_loss did not improve from 0.05045
#
# Epoch 00758: val_loss did not improve from 0.05045
#
# Epoch 00759: val_loss did not improve from 0.05045
#
# Epoch 00760: val_loss did not improve from 0.05045
#
# Epoch 00761: val_loss did not improve from 0.05045
#
# Epoch 00762: val_loss did not improve from 0.05045
#
# Epoch 00763: val_loss improved from 0.05045 to 0.04678, saving model to ./model4/763-0.0468.hdf5
#
# Epoch 00764: val_loss did not improve from 0.04678
#
# Epoch 00765: val_loss did not improve from 0.04678
#
# Epoch 00766: val_loss did not improve from 0.04678
#
# Epoch 00767: val_loss did not improve from 0.04678
#
# Epoch 00768: val_loss did not improve from 0.04678
#
# Epoch 00769: val_loss did not improve from 0.04678
#
# Epoch 00770: val_loss did not improve from 0.04678
#
# Epoch 00771: val_loss did not improve from 0.04678
#
# Epoch 00772: val_loss did not improve from 0.04678
#
# Epoch 00773: val_loss did not improve from 0.04678
#
# Epoch 00774: val_loss did not improve from 0.04678
#
# Epoch 00775: val_loss did not improve from 0.04678
#
# Epoch 00776: val_loss did not improve from 0.04678
#
# Epoch 00777: val_loss did not improve from 0.04678
#
# Epoch 00778: val_loss did not improve from 0.04678
#
# Epoch 00779: val_loss did not improve from 0.04678
#
# Epoch 00780: val_loss did not improve from 0.04678
#
# Epoch 00781: val_loss did not improve from 0.04678
#
# Epoch 00782: val_loss did not improve from 0.04678
#
# Epoch 00783: val_loss did not improve from 0.04678
#
# Epoch 00784: val_loss did not improve from 0.04678
#
# Epoch 00785: val_loss did not improve from 0.04678
#
# Epoch 00786: val_loss did not improve from 0.04678
#
# Epoch 00787: val_loss did not improve from 0.04678
#
# Epoch 00788: val_loss did not improve from 0.04678
#
# Epoch 00789: val_loss did not improve from 0.04678
#
# Epoch 00790: val_loss did not improve from 0.04678
#
# Epoch 00791: val_loss did not improve from 0.04678
#
# Epoch 00792: val_loss did not improve from 0.04678
#
# Epoch 00793: val_loss did not improve from 0.04678
#
# Epoch 00794: val_loss did not improve from 0.04678
#
# Epoch 00795: val_loss did not improve from 0.04678
#
# Epoch 00796: val_loss did not improve from 0.04678
#
# Epoch 00797: val_loss did not improve from 0.04678
#
# Epoch 00798: val_loss did not improve from 0.04678
#
# Epoch 00799: val_loss did not improve from 0.04678
#
# Epoch 00800: val_loss did not improve from 0.04678
#
# Epoch 00801: val_loss did not improve from 0.04678
#
# Epoch 00802: val_loss did not improve from 0.04678
#
# Epoch 00803: val_loss did not improve from 0.04678
#
# Epoch 00804: val_loss did not improve from 0.04678
#
# Epoch 00805: val_loss did not improve from 0.04678
#
# Epoch 00806: val_loss did not improve from 0.04678
#
# Epoch 00807: val_loss did not improve from 0.04678
#
# Epoch 00808: val_loss did not improve from 0.04678
#
# Epoch 00809: val_loss did not improve from 0.04678
#
# Epoch 00810: val_loss did not improve from 0.04678
#
# Epoch 00811: val_loss did not improve from 0.04678
#
# Epoch 00812: val_loss did not improve from 0.04678
#
# Epoch 00813: val_loss did not improve from 0.04678
#
# Epoch 00814: val_loss did not improve from 0.04678
#
# Epoch 00815: val_loss did not improve from 0.04678
#
# Epoch 00816: val_loss did not improve from 0.04678
#
# Epoch 00817: val_loss did not improve from 0.04678
#
# Epoch 00818: val_loss did not improve from 0.04678
#
# Epoch 00819: val_loss did not improve from 0.04678
#
# Epoch 00820: val_loss did not improve from 0.04678
#
# Epoch 00821: val_loss did not improve from 0.04678
#
# Epoch 00822: val_loss did not improve from 0.04678
#
# Epoch 00823: val_loss did not improve from 0.04678
#
# Epoch 00824: val_loss did not improve from 0.04678
#
# Epoch 00825: val_loss did not improve from 0.04678
#
# Epoch 00826: val_loss did not improve from 0.04678
#
# Epoch 00827: val_loss did not improve from 0.04678
#
# Epoch 00828: val_loss did not improve from 0.04678
#
# Epoch 00829: val_loss did not improve from 0.04678
#
# Epoch 00830: val_loss did not improve from 0.04678
#
# Epoch 00831: val_loss did not improve from 0.04678
#
# Epoch 00832: val_loss did not improve from 0.04678
#
# Epoch 00833: val_loss did not improve from 0.04678
#
# Epoch 00834: val_loss did not improve from 0.04678
#
# Epoch 00835: val_loss did not improve from 0.04678
#
# Epoch 00836: val_loss did not improve from 0.04678
#
# Epoch 00837: val_loss did not improve from 0.04678
#
# Epoch 00838: val_loss did not improve from 0.04678
#
# Epoch 00839: val_loss did not improve from 0.04678
#
# Epoch 00840: val_loss did not improve from 0.04678
#
# Epoch 00841: val_loss did not improve from 0.04678
#
# Epoch 00842: val_loss did not improve from 0.04678
#
# Epoch 00843: val_loss did not improve from 0.04678
#
# Epoch 00844: val_loss did not improve from 0.04678
#
# Epoch 00845: val_loss did not improve from 0.04678
#
# Epoch 00846: val_loss did not improve from 0.04678
#
# Epoch 00847: val_loss did not improve from 0.04678
#
# Epoch 00848: val_loss did not improve from 0.04678
#
# Epoch 00849: val_loss did not improve from 0.04678
#
# Epoch 00850: val_loss did not improve from 0.04678
#
# Epoch 00851: val_loss did not improve from 0.04678
#
# Epoch 00852: val_loss did not improve from 0.04678
#
# Epoch 00853: val_loss did not improve from 0.04678
#
# Epoch 00854: val_loss did not improve from 0.04678
#
# Epoch 00855: val_loss did not improve from 0.04678
#
# Epoch 00856: val_loss did not improve from 0.04678
#
# Epoch 00857: val_loss did not improve from 0.04678
#
# Epoch 00858: val_loss did not improve from 0.04678
#
# Epoch 00859: val_loss did not improve from 0.04678
#
# Epoch 00860: val_loss did not improve from 0.04678
#
# Epoch 00861: val_loss did not improve from 0.04678
#
# Epoch 00862: val_loss did not improve from 0.04678
#
# Epoch 00863: val_loss did not improve from 0.04678

# %%
from keras.models import load_model
del model
model = load_model('model4/763-0.0468.hdf5')
print("\n Accuracy: %.4f" % (model.evaluate(X, Y)[1]))
# Out:
# 975/975 [==============================] - 0s 54us/step
#
#  Accuracy: 0.9877
